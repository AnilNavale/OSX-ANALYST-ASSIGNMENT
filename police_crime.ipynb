# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("police_department_data.csv")

# %%
df
# Out:
#         incident_id        category  \
# 0         120058272     WEAPON LAWS
# 1         120058272     WEAPON LAWS
# 2         141059263        WARRANTS
# 3         160013662    NON-CRIMINAL
# 4         160002740    NON-CRIMINAL
# ...             ...             ...
# 150495    161061000         ASSAULT
# 150496    176000742    NON-CRIMINAL
# 150497    176000758   LARCENY/THEFT
# 150498    176000764   LARCENY/THEFT
# 150499    179002868  OTHER OFFENSES
#
#                                         crime_description  \
# 0                               POSS OF PROHIBITED WEAPON
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2                                          WARRANT ARREST
# 3                                           LOST PROPERTY
# 4                                           LOST PROPERTY
# ...                                                   ...
# 150495                                            BATTERY
# ...

# %%
print(df.isna().sum())
# Out:
# incident_id            0
# category               0
# crime_description      0
# crime_date             0
# department_district    1
# resolution             0
# address                0
# department_id          0
# location               0
# dtype: int64

# %%
ax = sns.countplot(x = "department_district", data=df, palette='rainbow')
ax.tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.style.use('dark_background')
plt.show()

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
df['crime_description'].value_counts()
# Out:
# GRAND THEFT FROM LOCKED AUTO                           17741
# LOST PROPERTY                                           4596
# AIDED CASE, MENTAL DISTURBED                            4566
# PETTY THEFT OF PROPERTY                                 4416
# MALICIOUS MISCHIEF, VANDALISM                           4262
#                                                        ...
# BURGLARY,WAREHOUSE UNDER CONSTRT, ATT. FORCIBLE            1
# ATTEMPTED ROBBERY CHAIN STORE WITH A KNIFE                 1
# TRADE SECRETS, THEFT OR UNAUTHORIZED COPYING               1
# WEAPON, ASSAULT, REGISTRATION OR TRANSFER VIOLATION        1
# ATTEMPTED MAYHEM WITH A DEADLY WEAPON                      1
# Name: crime_description, Length: 726, dtype: int64

# %%
df['crime_description'].value_counts()
# Out:
# GRAND THEFT FROM LOCKED AUTO                           17741
# LOST PROPERTY                                           4596
# AIDED CASE, MENTAL DISTURBED                            4566
# PETTY THEFT OF PROPERTY                                 4416
# MALICIOUS MISCHIEF, VANDALISM                           4262
#                                                        ...
# BURGLARY,WAREHOUSE UNDER CONSTRT, ATT. FORCIBLE            1
# ATTEMPTED ROBBERY CHAIN STORE WITH A KNIFE                 1
# TRADE SECRETS, THEFT OR UNAUTHORIZED COPYING               1
# WEAPON, ASSAULT, REGISTRATION OR TRANSFER VIOLATION        1
# ATTEMPTED MAYHEM WITH A DEADLY WEAPON                      1
# Name: crime_description, Length: 726, dtype: int64

# %%
df["crime_date"].value_counts()
# Out:
# 2016-01-01 00:01:00    68
# 2016-08-25 12:00:00    46
# 2016-02-04 12:00:00    42
# 2016-07-01 00:01:00    40
# 2016-01-01 12:00:00    39
#                        ..
# 2016-08-16 11:50:00     1
# 2016-08-16 13:36:00     1
# 2016-08-16 08:22:00     1
# 2016-08-15 14:35:00     1
# 2016-12-30 21:01:00     1
# Name: crime_date, Length: 67140, dtype: int64

# %%
df["crime_date"].dtype
# Out:
# dtype('O')

# %%
df['crime_date'][0][0:7]
# Out:
# '2016-01'

# %%
df['month'] = df['crime_date'].apply(lambda x:x[0:7])

# %%
df["COUNTER"] =1

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
# !pip install dataprep
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
order = df["department_district"].value_counts().index
ax = sns.countplot(x = "department_district", data=df, palette='rainbow',order=order[:8])
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
order = df["category"].value_counts().index
ax = sns.countplot(x = "category", data=df, palette='rainbow',order=order[:8])
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
order = df["resolution"].value_counts().index
ax = sns.countplot(x = "resolution", data=df, palette='rainbow',order=order[:6])
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
order = df["crime_description"].value_counts().index
ax = sns.countplot(x = "crime_description", data=df, palette='rainbow',order=order[:8])
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
order = df["address"].value_counts().index
ax = sns.countplot(x = "address", data=df, palette='rainbow',order=order[:5])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.show()

# %%
sns.set_style('darkgrid')
plt.style.use('seaborn-darkgrid')

# %%
import dask.dataframe as dd

# %%
df_2 = dd.read_csv("police_department_data.csv")

# %%
df_2.describe().compute()
# Out:
#         incident_id  department_id
# count  1.505000e+05   1.505000e+05
# mean   1.616440e+08   1.616440e+13
# std    5.535976e+06   5.535976e+11
# min    1.135121e+07   1.135121e+12
# 25%    1.603283e+08   1.603283e+13
# 50%    1.606541e+08   1.606541e+13
# 75%    1.609764e+08   1.609764e+13
# max    9.910090e+08   9.910090e+13

# %%
df_2['month'] = df_2['crime_date'].apply(lambda x:x[0:7])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\core.py:3997: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('crime_date', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
df_2["COUNTER"] =1

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
df["crime_date"][5250]
# Out:
# '2016-03-15 16:15:00'

# %%
df["crime_date"][5250][11:13]
# Out:
# '16'

# %%
df["hour"]=df["crime_date"].apply(lambda x:x[11:13])

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
df['hour'].value_counts()
# Out:
# 18    9718
# 17    9559
# 12    9021
# 19    8981
# 16    8656
# 15    8329
# 20    8098
# 14    7621
# 21    7480
# 13    7268
# 22    7099
# 00    6941
# 11    6786
# 23    6573
# 10    6483
# 09    5865
# 08    5575
# 01    4359
# 07    3894
# 02    3494
# 03    2553
# 06    2518
# 04    1885
# 05    1744
# Name: hour, dtype: int64

# %%
df_2['hour'] = df_2['crime_date'].apply(lambda x:x[11:13])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\core.py:3997: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('crime_date', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
plt.figure(figsize=(18,5))
df_2.groupby('month').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by Year and Month")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by Year and Month')

# %%
plt.figure(figsize=(18,6))
df_2.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour')

# %%
#in this graph we can see total number of Report in a day by hour

# %%
df_crime = df_2[df_2["crime_description"]=="STOLEN AUTOMOBILE"]

# %%
plt.figure(figsize=(18,6))
df_crime.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases of STOLEN AUTOMOBILE")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases of STOLEN AUTOMOBILE')

# %%
df_Locked_auto = df_2[df_2["crime_description"]=="GRAND THEFT FROM LOCKED AUTO"]

# %%
df_Lost_property = df_2[df_2["crime_description"]=="LOST PROPERTY"]

# %%
df_crime = df_2[df_2["crime_description"]=="STOLEN AUTOMOBILE"]

# %%
plt.figure(figsize=(18,6))
df_Locked_auto.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases of GRAND THEFT FROM LOCKED AUTO")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases of GRAND THEFT FROM LOCKED AUTO')

# %%
plt.figure(figsize=(18,6))
df_Lost_property.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases of LOST PROPERTY")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases of LOST PROPERTY')

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
df["address"].value_counts()
# Out:
# 800 Block of BRYANT ST         3561
# 800 Block of MARKET ST         1405
# 1000 Block of POTRERO AV        644
# 900 Block of MARKET ST          547
# 0 Block of UNITEDNATIONS PZ     452
#                                ...
# UNIVERSITY ST / WOOLSEY ST        1
# EUGENIA AV / GATES ST             1
# 0 Block of UPLAND DR              1
# BALBOA ST / 24TH AV               1
# 1800 Block of 26TH AV             1
# Name: address, Length: 16130, dtype: int64

# %%
df_bryant = df_2[df_2["address"] == "800 Block of BRYANT ST"]

# %%
df_market = df_2[df_2["address"] == "800 Block of MARKET ST"]

# %%
df_potrero = df_2[df_2["address"] == "1000 Block of POTRERO AV"]

# %%
plt.figure(figsize=(18,6))
df_bryant.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases at 800 Block of BRYANT ST ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases at 800 Block of BRYANT ST ')

# %%
plt.figure(figsize=(18,6))
df_market.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases at 800 Block of MARKET ST ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases at 800 Block of MARKET ST ')

# %%
plt.figure(figsize=(18,6))
df_potrero.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases at 1000 Block of POTRERO AV ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases at 1000 Block of POTRERO AV ')

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
df["category"].value_counts()
# Out:
# LARCENY/THEFT                  40409
# OTHER OFFENSES                 19599
# NON-CRIMINAL                   17866
# ASSAULT                        13577
# VANDALISM                       8589
# VEHICLE THEFT                   6419
# WARRANTS                        5914
# BURGLARY                        5802
# SUSPICIOUS OCC                  5782
# MISSING PERSON                  4338
# DRUG/NARCOTIC                   4243
# ROBBERY                         3299
# FRAUD                           2635
# SECONDARY CODES                 1841
# TRESPASS                        1812
# WEAPON LAWS                     1658
# SEX OFFENSES, FORCIBLE           940
# STOLEN PROPERTY                  882
# RECOVERED VEHICLE                736
# DISORDERLY CONDUCT               658
# PROSTITUTION                     641
# FORGERY/COUNTERFEITING           619
# DRUNKENNESS                      465
# DRIVING UNDER THE INFLUENCE      378
# ARSON                            286
# ...

# %%
df_weapon = df[df["category"] == "WEAPON LAWS"]

# %%
order = df_weapon["department_district"].value_counts().index
ax = sns.countplot(x = "department_district", data=df_weapon, palette='rainbow',order=order[:5])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.title("CASES OF WEAPON LAWS BY DEPARTMENT")
plt.show()

# %%
order = df_weapon["address"].value_counts().index
ax = sns.countplot(x = "address", data=df_weapon, palette='rainbow',order=order[:5])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.title("CASES OF WEAPON LAWS BY DEPARTMENT")
plt.show()

# %%
plt.figure(figsize=(18,6))
df_weapon.groupby('hour').count()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases WEAPON LAWS ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases WEAPON LAWS ')

# %%
df_burglary = df_2[df_2["category"]=="BURGLARY"]

# %%
plt.figure(figsize=(18,6))
df_burglary.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases BURGLARY ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases BURGLARY ')

# %%
df_burglary["department_district"].value_counts().compute()
# Out:
# SOUTHERN      842
# NORTHERN      803
# MISSION       793
# TARAVAL       695
# CENTRAL       645
# INGLESIDE     534
# BAYVIEW       521
# PARK          413
# RICHMOND      395
# TENDERLOIN    161
# Name: department_district, dtype: int64

# %%
df["lat"][0]
# Out:
# 37.775420706711

# %%
df["lat"] = df['location'].apply(lambda x : x.split(',')[0][1:])

# %%
df["long"] = df['location'].apply(lambda x : x.split(',')[1][:-1])

# %%
df["lat"] = df['lat'].apply(lambda x : float(x))

# %%
df["long"] = df['long'].apply(lambda x : float(x))

# %%
crime_vso_locations=df[df['category']=="ASSAULT"].groupby(['lat','long']).sum()['COUNTER'].reset_index()
crime_vso_locations.sort_values(by='COUNTER',ascending=False,inplace=True)
crime_vso_locations=crime_vso_locations.head(25)

# %%
import plotly.express as px
fig=px.scatter_mapbox(crime_vso_locations, lat="lat", lon="long",color="COUNTER",size="COUNTER",
                      title="Top 25 locations with the highest volume ASSUALT",
                      color_continuous_scale=px.colors.sequential.thermal)
fig.update_layout(mapbox_style="carto-positron")
fig.show()
# Out:
# <div>                            <div id="44889305-d71a-45a1-8a61-ec92fbce5564" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44889305-d71a-45a1-8a61-ec92fbce5564")) {                    Plotly.newPlot(                        "44889305-d71a-45a1-8a61-ec92fbce5564",                        [{"hovertemplate":"COUNTER=%{marker.color}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","lat":[37.7835100715421,37.789918101686,37.7861517236899,37.7245556697717,37.7216221726261,37.7143615498756,37.7870966495663,37.775420706711,37.7540986882068,37.7650501214668,37.7841847091303,37.7285280627465,37.8070362071183,37.7830529510782,37.7827317884887,37.7821372491619,37.7823263368922,37.7572992974101,37.7809706722053,37.7825543452426,37.7831614109395,37.7576508232124,3
# ...

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
crime_vso_locations=df[df['category']=="MISSING PERSON"].groupby(['lat','long']).sum()['COUNTER'].reset_index()
crime_vso_locations.sort_values(by='COUNTER',ascending=False,inplace=True)
crime_vso_locations=crime_vso_locations.head(25)

# %%
import plotly.express as px
fig=px.scatter_mapbox(crime_vso_locations, lat="lat", lon="long",color="COUNTER",size="COUNTER",
                      title="Top 25 locations with the highest volume MISSING PERSON",
                      color_continuous_scale=px.colors.sequential.thermal)
fig.update_layout(mapbox_style="carto-positron")
fig.show()
# Out:
# <div>                            <div id="963c357c-18c9-4e3e-8ad6-ccbab2666cd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("963c357c-18c9-4e3e-8ad6-ccbab2666cd9")) {                    Plotly.newPlot(                        "963c357c-18c9-4e3e-8ad6-ccbab2666cd9",                        [{"hovertemplate":"COUNTER=%{marker.color}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","lat":[37.7738617771611,37.7226161363136,37.7382838346971,37.775420706711,37.7745145380854,37.7746354223627,37.7717273141771,37.7724682400061,37.7388214326705,37.7677738874748,37.7693759323628,37.7755529016833,37.7530927418726,37.7613161836641,37.7564864109309,37.7749629647565,37.774088474589,37.753084671409,37.7778540141174,37.7627436601147,37.7838344374141,37.8096707013239,37
# ...

# %%
crime_vso_locations=df[df['category']=="ROBBERY"].groupby(['lat','long']).sum()['COUNTER'].reset_index()
crime_vso_locations.sort_values(by='COUNTER',ascending=False,inplace=True)
crime_vso_locations=crime_vso_locations.head(25)

# %%
import plotly.express as px
fig=px.scatter_mapbox(crime_vso_locations, lat="lat", lon="long",color="COUNTER",size="COUNTER",
                      title="Top 25 locations with the highest volume ROBBERY",
                      color_continuous_scale=px.colors.sequential.thermal)
fig.update_layout(mapbox_style="carto-positron")
fig.show()
# Out:
# <div>                            <div id="95cd3ef7-e885-4509-87b3-3971c241c32b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95cd3ef7-e885-4509-87b3-3971c241c32b")) {                    Plotly.newPlot(                        "95cd3ef7-e885-4509-87b3-3971c241c32b",                        [{"hovertemplate":"COUNTER=%{marker.color}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","lat":[37.775420706711,37.7841893501425,37.7850629421661,37.7650501214668,37.7657184395282,37.7816542806076,37.7285280627465,37.7820729312029,37.7827317884887,37.7822305870036,37.7825851968467,37.7804777480508,37.7827931071006,37.7852071918419,37.7851670875517,37.7642205603745,37.7340152180723,37.7818621883021,37.769247063207,37.7799444052046,37.7835699386918,37.779514030063,37
# ...

# %%
crime_vso_locations=df[df['category']=="DRUG/NARCOTIC"].groupby(['lat','long']).sum()['COUNTER'].reset_index()
crime_vso_locations.sort_values(by='COUNTER',ascending=False,inplace=True)
crime_vso_locations=crime_vso_locations.head(25)

# %%
import plotly.express as px
fig=px.scatter_mapbox(crime_vso_locations, lat="lat", lon="long",color="COUNTER",size="COUNTER",
                      title="Top 25 locations with the highest volume DRUG/NARCOTIC",
                      color_continuous_scale=px.colors.sequential.thermal)
fig.update_layout(mapbox_style="carto-positron")
fig.show()
# Out:
# <div>                            <div id="d6d9930d-3fd7-4f10-a2d7-e118a4cc6163" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6d9930d-3fd7-4f10-a2d7-e118a4cc6163")) {                    Plotly.newPlot(                        "d6d9930d-3fd7-4f10-a2d7-e118a4cc6163",                        [{"hovertemplate":"COUNTER=%{marker.color}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","lat":[37.7816542806076,37.7825851968467,37.7799444052046,37.7805345385278,37.775420706711,37.7797870676495,37.7686969786551,37.7650501214668,37.7827931071006,37.7821198488931,37.7817511307229,37.7762310404758,37.7851670875517,37.7818621883021,37.7658427213372,37.7832593295025,37.781863316866,37.7564864109309,37.7832583770949,37.7809039696758,37.7809706722053,37.7821372997842,3
# ...

# %%
crime_vso_locations=df[df['category']=="VEHICLE THEFT"].groupby(['lat','long']).sum()['COUNTER'].reset_index()
crime_vso_locations.sort_values(by='COUNTER',ascending=False,inplace=True)
crime_vso_locations=crime_vso_locations.head(25)

# %%
import plotly.express as px
fig=px.scatter_mapbox(crime_vso_locations, lat="lat", lon="long",color="COUNTER",size="COUNTER",
                      title="Top 25 locations with the highest volume VEHICLE THEFT",
                      color_continuous_scale=px.colors.sequential.thermal)
fig.update_layout(mapbox_style="carto-positron")
fig.show()
# Out:
# <div>                            <div id="b3b927c9-8ba8-484b-9563-f9789c00eae3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3b927c9-8ba8-484b-9563-f9789c00eae3")) {                    Plotly.newPlot(                        "b3b927c9-8ba8-484b-9563-f9789c00eae3",                        [{"hovertemplate":"COUNTER=%{marker.color}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","lat":[37.7835100715421,37.789918101686,37.7861517236899,37.7245556697717,37.7216221726261,37.7143615498756,37.7870966495663,37.775420706711,37.7540986882068,37.7650501214668,37.7841847091303,37.7285280627465,37.8070362071183,37.7830529510782,37.7827317884887,37.7821372491619,37.7823263368922,37.7572992974101,37.7809706722053,37.7825543452426,37.7831614109395,37.7576508232124,3
# ...

# %%
df['category'].isnull().values.any()
# Out:
# False

# %%
crime_type_df = df['category'].value_counts(ascending=True)


fig=plt.figure(figsize=(18, 16))
plt.title("Frequency of Crimes Per Crime Type")
plt.xlabel("Frequency of Crimes")
plt.ylabel("Type of Crime")
plt.style.use('dark_background')
ax = crime_type_df.plot(kind='barh')
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# %%
crime_type_df = df['resolution'].value_counts(ascending=True)


fig=plt.figure(figsize=(14, 12))
plt.title("Frequency of resolution")
plt.xlabel("Frequency of resolution")
plt.ylabel("Type ofresolution")
plt.style.use('dark_background')
ax = crime_type_df.plot(kind='barh')
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# %%
from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (10,10)
plt.style.use('fast')

wc = WordCloud(background_color = 'red', width = 1500, height = 1500).generate(str(df['category']))
plt.title('Description of the Crime', fontsize = 25)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud

# %%
plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('fivethirtyeight')

color = plt.cm.ocean(np.linspace(0, 1, 15))
df['address'].value_counts().head(15).plot.bar(color = color)

plt.title('Top 10 Regions in Crime',fontsize = 20)
plt.xticks(rotation = 90)
plt.show()
